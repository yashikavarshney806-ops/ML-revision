# %%
import numpy as np 
import pandas as pd

# %%
from sklearn.datasets import make_regression

# %%
X,y=make_regression(n_samples=4,n_features=1,n_informative=1,n_targets=1,noise=80,random_state=13)

# %%
import matplotlib.pyplot as plt 
plt.scatter(X,y)

# %%
# applying OLS using sklearn
from sklearn.linear_model import LinearRegression
reg=LinearRegression()
reg.fit(X,y)
# Out:
# LinearRegression()

# %%
reg.coef_
# Out:
# array([78.35063668])

# %%
reg.intercept_
# Out:
# np.float64(26.15963284313262)

# %%
plt.scatter(X,y)
plt.plot(X,reg.predict(X),c='r')

# %%
# let's intercept = 0  
#  y= mx + b --> slope of line
y_pred=((78.35 * X) + 0).reshape(4)
y_pred
# Out:
# array([-55.81580837,  35.39949674,  -3.48681619,  59.05759577])

# %%
plt.scatter(X,y)
plt.plot(X,reg.predict(X),color='red',label='OLS')
plt.plot(X,y_pred,color='g',label='b=0')
plt.legend()
plt.show()

# %%
#  calculating slope as in thr copy 
m=78.35
b=0

loss_slope= -2*np.sum(y - m * X.ravel() - b) # this is not the slope of line 
                    #   this is the slope of loss funcction
loss_slope
# Out:
# np.float64(-209.27763408209216)

# %%
# lets learning rate is 0.1
lr=0.1

step_size=loss_slope*lr
step_size
# Out:
# np.float64(-20.927763408209216)

# %%
b=b-step_size
b
# Out:
# np.float64(20.927763408209216)

# %%
y_pred1=((78.35*X)+b).reshape(4)
y_pred
# Out:
# array([-55.81580837,  35.39949674,  -3.48681619,  59.05759577])

# %%
plt.scatter(X,y)
plt.plot(X,reg.predict(X),color='r',label='OLS')
plt.plot(X,y_pred1,color='#00a65a',label=f'b={b}')
plt.plot(X,y_pred,color='#A3E4D7',label='b=0')
plt.legend()
plt.show()

# %%
# iteration 2
loss_slope= -2 * np.sum(y - m*X.ravel() - b)
loss_slope
# Out:
# np.float64(-41.85552681641843)

# %%
b=b-lr*loss_slope
b
# Out:
# np.float64(25.11331608985106)

# %%
y_pred12=((78.35*X)+b).reshape(4)
y_pred12
# Out:
# array([-30.70249228,  60.51281283,  21.6264999 ,  84.17091186])

# %%
plt.scatter(X,y)
plt.plot(X,reg.predict(X),color='r',label='OLS')
plt.plot(X,y_pred1,color='#00a65a',label=f'b={b}')
plt.plot(X,y_pred,color='#A3E4D7',label='b=0')
plt.plot(X,y_pred12,color="#23302D",label='b=0')
plt.legend()
plt.show()

# %%
# iteration 3
loss_slope= -2 * np.sum(y - m*X.ravel() - b)
loss_slope
# Out:
# np.float64(-8.371105363283675)

# %%
b=b-lr*loss_slope
b
# Out:
# np.float64(25.95042662617943)

# %%
X,y=make_regression(n_samples=100,n_features=1,n_informative=1,n_targets=1,noise=20,random_state=13)
plt.scatter(X,y)

# %%
from sklearn.linear_model import LinearRegression
linear=LinearRegression()

# %%
linear.fit(X,y)
# Out:
# LinearRegression()

# %%
linear.coef_
# Out:
# array([27.82809103])

# %%
linear.intercept_
# Out:
# np.float64(-2.29474455867698)

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.25,random_state=42)

# %%
y_pred=linear.predict(X_test)
from sklearn.metrics import r2_score
r2_score(y_test,y_pred)
# Out:
# 0.6505910575757232

# %%
class GDRegressor :
    def __init__(self,epochs,lrate):
        self.m= 675
        self.b= -120
        self.epochs=epochs
        self.lr=lrate

    def fit(self,X,y):
        for i in range(self.epochs):
            loss_slope_b = -2 * np.sum(y - self.m*X.ravel() - self.b)
            loss_slope_m = -2 * np.sum((y - self.m*X.ravel() - self.b)*X.ravel())
            self.b=self.b-self.lr*loss_slope_b
            self.m=self.m-self.lr*loss_slope_m
            
        print(self.m,self.b)

    def predict(self,X):
        return self.m * X.ravel() + self.b

# %%
gd=GDRegressor(50,0.001)

# %%
gd.fit(X,y)
# Out:
# 27.883244993921128 -2.314681985404932

# %%
y_pred=gd.predict(X_test)

# %%
r2_score(y_test,y_pred)
# Out:
# 0.650482196307892

# %%
import time
def decorator(func):
    def wrapper(*args):
        start=time.time()
        func(*args)
        end=time.time()
        print("time taken by",func.__name__,'is',start-end)
    return wrapper

@decorator
def function():
    print("Hello babes!!")
    time.sleep(2)

function()
# Out:
# Hello babes!!
# time taken by function is -2.00072979927063

# %%
from sklearn.datasets import load_diabetes

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score

# %%
X,y=load_diabetes(return_X_y=True)
print(X.shape)
print(y.shape)
X
# Out:
# (442, 10)
# (442,)
# array([[ 0.03807591,  0.05068012,  0.06169621, ..., -0.00259226,
#          0.01990749, -0.01764613],
#        [-0.00188202, -0.04464164, -0.05147406, ..., -0.03949338,
#         -0.06833155, -0.09220405],
#        [ 0.08529891,  0.05068012,  0.04445121, ..., -0.00259226,
#          0.00286131, -0.02593034],
#        ...,
#        [ 0.04170844,  0.05068012, -0.01590626, ..., -0.01107952,
#         -0.04688253,  0.01549073],
#        [-0.04547248, -0.04464164,  0.03906215, ...,  0.02655962,
#          0.04452873, -0.02593034],
#        [-0.04547248, -0.04464164, -0.0730303 , ..., -0.03949338,
#         -0.00422151,  0.00306441]], shape=(442, 10))

# %%
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.2,random_state=2)

# %%
reg=LinearRegression()
reg.fit(X_train,y_train)
reg.coef_
# Out:
# array([  -9.15865318, -205.45432163,  516.69374454,  340.61999905,
#        -895.5520019 ,  561.22067904,  153.89310954,  126.73139688,
#         861.12700152,   52.42112238])

# %%
reg.intercept_
# Out:
# np.float64(151.88331005254167)

# %%
y_pred=reg.predict(X_test)
r2_score(y_test,y_pred)
# Out:
# 0.439933866156897

# %%
class MGDRegressor:
    def __init__(self,learning_rate=0.01,epochs=100):
        self.coef_ = None
        self.intercept_ = None
        self.lr=learning_rate
        self.epochs=epochs

    def fit(self,X_train,y_train):
        
        self.coef_ = np.ones(X_train.shape[1])
        self.intercept_ = 0

        for i in range(self.epochs):
            y_hat=np.dot(X_train,self.coef_) + self.intercept_
            intercept_der= -2 * np.mean((y_train-y_hat))
            self.intercept_=self.intercept_ - (self.lr * intercept_der)

            coef_der= -2 * np.dot((y_train-y_hat),X_train)/X_train.shape[0]
            self.coef_=self.coef_ -  (self.lr*coef_der)
        print(self.intercept_,self.coef_)

    def predict(self,X_test):
        return np.dot(X_test,self.coef_) + self.intercept_

# %%
mgdr=MGDRegressor(learning_rate=0.1,epochs=150)

# %%
mgdr.fit(X_train,y_train)
# Out:
# 150.8859603153993 [ 22.33589294   4.27129732  60.36801248  46.83825327  20.37135134
#   15.44798534 -36.23662237  39.27819427  59.34407908  35.7717813 ]

# %%
y_pred=mgdr.predict(X_test)

# %%
r2_score(y_test,y_pred)
# Out:
# 0.1479967742959326

# %%
class SGDRegressor:
    def __init__(self,learning_rate=0.01,epochs=100):
        self.coef_ = np.ones(X_train.shape[1])
        self.intercept_ = 0
        self.lr=learning_rate
        self.epochs=epochs

    def fit(self,X_train,y_train):
        for i in range(self.epochs):
           for j in range(X_train.shape[0]):
                
                idx=np.random.randint(0,X_train.shape[0])
                y_hat=np.dot(X_train[idx],self.coef_)  + self.intercept_
                
                intercept_der= -2 * (y_train[idx]-y_hat)
                self.intercept_= self.intercept_ - self.lr*intercept_der
                
                coef_der= -2 * np.dot((y_train[idx]-y_hat),X_train[idx])
                self.coef_=self.coef_ - self.lr * coef_der 


        print(self.intercept_,self.coef_)

    def predict(self,X_test):
        return np.dot(X_test,self.coef_) + self.intercept_

# %%
sgd=SGDRegressor(learning_rate=0.01,epochs=50)

# %%
sgd.fit(X_train,y_train)
# Out:
# 151.7046545558722 [  51.63328859  -73.87763234  352.49698388  249.08957987   21.17053522
#   -26.13655586 -169.92677419  129.53127854  320.67948856  133.41256275]

# %%
y_pred=sgd.predict(X_test)
y_pred
# Out:
# array([154.09566316, 191.45603021, 139.00258828, 109.38123352,
#        244.06971104, 235.46299132, 107.53251674, 114.7466641 ,
#         92.69597323, 184.61975851, 160.6362947 , 171.34278922,
#        183.55917601, 151.0954128 , 253.86885349,  92.91376595,
#        185.80565844, 139.40281459, 139.72401496, 138.23007243,
#        132.28759241, 190.62452128, 165.667474  , 177.50866498,
#        126.70798234, 220.42022613, 194.53837713, 121.6409469 ,
#         62.82905216, 241.46262245, 236.83588897, 119.29050344,
#         75.01685845, 109.60763465, 199.45080141, 166.36395589,
#        166.56489424, 195.45506644, 115.28574008, 233.15155807,
#        135.5308322 , 126.2317029 , 185.00617428, 185.68929229,
#        169.17011713, 145.49896932, 172.70709226, 277.1590603 ,
#        116.78174053, 188.59394101, 236.28777541, 130.14044462,
#        143.63547727, 149.447716  , 188.80119521, 112.85712787,
#        155.23029349,  86.77067736, 158.91211924, 143.6266718 ,
#        162.77304167, 170.53746987, 111.09272026, 205.10765489,
#        156.40017456, 153.57053593, 149.95513269, 187.55156344,
#        121.57516733, 143.11809157, 201.75003047, 186.99236953,
#        120.26264209, 149.90388425, 140.99580374, 114.64379124,
#         86.88740722,  88.87540533, 170.17605304,  89.58229536,
#         99.87882867, 108.01444828, 165.08326658, 258.00548211,
#        200.03726365, 140.43564688, 250.23146797, 184.71389161,
#        113.57781769])

# %%
sgd.coef_
# Out:
# array([  51.63328859,  -73.87763234,  352.49698388,  249.08957987,
#          21.17053522,  -26.13655586, -169.92677419,  129.53127854,
#         320.67948856,  133.41256275])

# %%
sgd.intercept_
# Out:
# np.float64(151.7046545558722)

# %%
r2_score(y_test,y_pred)
# Out:
# 0.4348576877438174

# %%
from sklearn.linear_model import SGDRegressor

# %%
reg=SGDRegressor(max_iter=100,learning_rate='constant',eta0=0.01)

# %%
reg.fit(X_train,y_train)
# Out:
# C:\Users\yashi\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\sklearn\linear_model\_stochastic_gradient.py:1612: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(
# SGDRegressor(learning_rate='constant', max_iter=100)

# %%
y_pred=reg.predict(X_test)
y_pred
# Out:
# array([157.01439934, 194.01717629, 143.33920073, 112.61201983,
#        246.78873978, 239.11907244, 111.05041772, 118.40716066,
#         96.73325953, 188.08423723, 163.61403221, 175.81336054,
#        187.40483747, 154.27472043, 255.95735309,  96.15284352,
#        188.60726586, 142.70388624, 143.44297058, 142.71032419,
#        136.05860204, 193.01105506, 169.87157099, 181.01293848,
#        130.09618053, 222.62544414, 197.78835619, 124.58288861,
#         67.57613074, 243.42982621, 238.80481414, 123.04748917,
#         79.09829414, 114.16900198, 202.49412495, 169.58759776,
#        170.2772713 , 199.02568067, 119.0339007 , 235.3600247 ,
#        139.42594631, 130.7285198 , 188.28362908, 189.20776798,
#        173.65093538, 149.6536569 , 176.67359252, 279.85058058,
#        121.54548907, 192.15375559, 238.48867759, 133.8852055 ,
#        147.0984903 , 153.93473485, 192.42287136, 117.69855748,
#        159.24228504,  90.30061785, 161.77334295, 147.04100183,
#        167.03194155, 174.56429731, 114.72344315, 207.7217433 ,
#        160.64097665, 157.23502092, 154.49413868, 190.94795863,
#        125.62812047, 146.99065544, 204.50608276, 189.72973664,
#        124.55041271, 153.94705394, 144.32242823, 118.27540137,
#         90.63754341,  93.63295778, 174.09559128,  93.92364104,
#        104.20745122, 113.64258769, 168.10509229, 260.27232459,
#        202.48917655, 143.60697562, 252.59453916, 187.9725159 ,
#        118.14520928])

# %%
r2_score(y_test,y_pred)
# Out:
# 0.43154790282534006

# %%
import random
# mini batch
class MBGDRegressor:
    def __init__(self,batch_size,learning_rate=0.01,epochs=100):
        self.coef_ = np.ones(X_train.shape[1])
        self.intercept_ = 0
        self.lr=learning_rate
        self.epochs=epochs
        self.batch_size=batch_size

    def fit(self,X_train,y_train):
        for i in range(self.epochs):
           for j in range(int(X_train.shape[0]/self.batch_size)):
                idx=random.sample(X_train.shape[0],self.batch_size)
                y_hat=np.dot(X_train[idx],self.coef_)+self.intercept_

                intercept_der= -2 * np.mean(y_train[idx]-y_hat)
                self.intercept_= self.intercept_ - self.lr*intercept_der
                
                coef_der= -2 * np.dot((y_train[idx]-y_hat),X_train[idx])
                self.coef_=self.coef_ - self.lr * coef_der 



        print(self.intercept_,self.coef_)

    def predict(self,X_test):
        return np.dot(X_test,self.coef_) + self.intercept_

# %%
mbgd=MBGDRegressor(batch_size=int(X_train.shape[0]/10),learning_rate=0.01,epochs=50)

# %%
mbgd.fit(X_train,y_train)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[77], line 1
# ----> 1 mbgd.fit(X_train,y_train)
#
# Cell In[75], line 14, in MBGDRegressor.fit(self, X_train, y_train)
#      12 for i in range(self.epochs):
#      13    for j in range(int(X_train.shape[0]/self.batch_size)):
# ---> 14         idx=random.sample(X_train.shape[0],self.batch_size)
#      15         y_hat=np.dot(X_train[idx],self.coef_)+self.intercept_
#      17         intercept_der= -2 * np.mean(y_train[idx]-y_hat)
#
# File C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.13_3.13.3568.0_x64__qbz5n2kfra8p0\Lib\random.py:417, in Random.sample(self, population, k, counts)
#     393 # Sampling without replacement entails tracking either potential
#     394 # selections (the pool) in a list or previous selections in a set.
#     395
#    (...)    413 # too many calls to _randbelow(), making them slower and
#     414 # causing them to eat more entropy than necessary.
#     416 if not isinstance(population, _Sequence):
# --> 417     raise TypeError("Population must be a sequence.  "
#     418                     "For dicts or sets, use sorted(d).")
#     419 n = len(population)
#     420 if counts is not None:
#
# TypeError: Population must be a sequence.  For dicts or sets, use sorted(d).

# %%
a=35
b=8

max_=max(a,b)
while True:
    if max_%a==0 and max_%b==0:
        break
    max_+=1
print(max_)
# Out:
# 280

# %%
def gcd(a,b):
    if b==0:
        return a
    return gcd(b,a%b)
print(gcd(12,24))
# Out:
# 12

# %%
def ana():
    a='listen'
    b='silent'
    count = {}
    for ch in a:
        count[ch]=count.get(ch,0)+1
    for ch in b:
        count[ch]=count.get(ch,0)-1
    for val in count.values():
        if val!=0:
            return (False)
    return True
print(ana())
# Out:
# True

# %%
ord('A')
# Out:
# 65
